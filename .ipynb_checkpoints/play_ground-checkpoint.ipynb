# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
# import data
df = pd.read_csv('epa-sea-level.csv')

# %%
# scatter plot
fig, ax = plt.subplots(figsize=(16, 8))
ax.plot(df['Year'], df['CSIRO Adjusted Sea Level'], 'o')
ax.set_xlabel('Year')
ax.set_ylabel('CSIRO Adjusted Sea Level')
# Out:
# Text(0, 0.5, 'CSIRO Adjusted Sea Level')

# %%
reg = stats.linregress(df['Year'], df['CSIRO Adjusted Sea Level'])
future_years = np.arange(1880, 2051)

# %%
# first line of best fit starts from 1880
fig, ax = plt.subplots(figsize=(16, 8))
ax.plot(x, y, 'o')
ax.plot(future_years, reg.intercept + reg.slope * future_years)

# %%
filtered = df[df['Year'] >= 2000]
res = stats.linregress(filtered['Year'], filtered['CSIRO Adjusted Sea Level'])
starts_2000 = np.arange(2000, 2051)

# %%
fig, ax = plt.subplots(figsize=(16, 8))
ax.plot(x, y, 'o')
ax.plot(future_years, reg.intercept + reg.slope * future_years)
ax.plot(starts_2000, res.intercept + res.slope * starts_2000)
ax.set_xlabel('Year')
ax.set_ylabel('Sea Level (inches)')
ax.set_title('Rise in Sea Level')
# Out:
# Text(0.5, 1.0, 'Rise in Sea Level')
